# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir(f"/content/drive/MyDrive/AI_or_Real_datasets/AIDE")

# %%
os.chdir(f"/content/drive/MyDrive/AI_or_Real_datasets/AIDE")
## --resume GenImage_train.pth \
##  --blr 1e-4 \
# !python main_finetune.py \
    --model AIDE \
    --batch_size 32 \
    --blr 1e-5 \
    --epochs 20 \
    --resume FT_indian_models_v2/checkpoint-2.pth \
    --output_dir FT_indian_models_v3
# Out:
# /usr/local/lib/python3.12/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# Not using distributed mode
# ...

# %%
# !pip install kornia
# !pip install kornia_rs
# !pip install tensorboardX
# !pip install open-clip-torch
# !pip install openai-clip
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 43.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 5.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 28.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for openai-clip: filename=openai_clip-1.0.1-py3-none-any.whl size=1368605 sha256=7092b2ee36266d5e38944f946783d34158435532c28f82957861650566598010
#   Stored in directory: /root/.cache/pip/wheels/ab/49/bc/c2342e8e14878210ba4825cf314a53f2570f6fb18b91fce3cf
# Successfully built openai-clip
# ...
